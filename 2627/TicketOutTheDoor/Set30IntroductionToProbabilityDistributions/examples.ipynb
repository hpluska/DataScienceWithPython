# %%
import numpy as np
import scipy.stats as stats

# Simulate 20 coin flips
coin = ["H", "T"]
flips = np.random.choice(coin, size=20, replace=True)

# Count heads
num_heads = np.sum(flips == "H")

# print(flips)
# print("Heads:", num_heads)


# stats.binom.pmf(x, n, p)
for k in range(11):
    print("P(X = {k}) = {stat}".format(k = k, 
    stat = round(stats.binom.pmf(k, 10, 0.5),6)))

# print(stats.binom.pmf(2, n=10, p=.5) + stats.binom.pmf(3, n=10, p=.5) + stats.binom.pmf(4, n=10, p=.5))

import scipy.stats as stats

flips_0_8 = stats.binom.pmf(0, n = 10, p = 0.5)
flips_0_8 += stats.binom.pmf(1, n = 10, p = 0.5)
flips_0_8 += stats.binom.pmf(2, n = 10, p = 0.5)
flips_0_8 += stats.binom.pmf(3, n = 10, p = 0.5)
flips_0_8 += stats.binom.pmf(4, n = 10, p = 0.5)
flips_0_8 += stats.binom.pmf(5, n = 10, p = 0.5)
flips_0_8 += stats.binom.pmf(6, n = 10, p = 0.5)
flips_0_8 += stats.binom.pmf(7, n = 10, p = 0.5)
flips_0_8 += stats.binom.pmf(8, n = 10, p = 0.5)

print(flips_0_8)

import scipy.stats as stats
# less than or equal to 8
flips_0_8 = 1 - (stats.binom.pmf(9, n=10, p=.5) + stats.binom.pmf(10, n=10, p=.5))
print(flips_0_8)


n = 8
p = 1/6

prob = 0
for k in range(1, 4):   # 1, 2, 3
    prob += stats.binom.pmf(k, n, p)

print(prob)
# Out:
# P(X = 0) = 0.000977
# P(X = 1) = 0.009766
# P(X = 2) = 0.043945
# P(X = 3) = 0.117188
# P(X = 4) = 0.205078
# P(X = 5) = 0.246094
# P(X = 6) = 0.205078
# P(X = 7) = 0.117187
# P(X = 8) = 0.043945
# P(X = 9) = 0.009766
# P(X = 10) = 0.000977
# 0.9892578124999999
# 0.9892578125
# 0.7367755486968451

# %%
print(stats.binom.cdf(6, 10, 0.5))


import scipy.stats as stats

print(stats.binom.cdf(6, 10, 0.5) - stats.binom.cdf(2, 10, 0.5))


print(1 - stats.binom.cdf(6, 10, 0.5))



# stats.norm.cdf(x, loc, scale)
print(stats.norm.cdf(158, 167.64, 8))
print(stats.norm.cdf(175, 167.74, 8) - stats.norm.cdf(165, 167.74, 8))
# Out:
# 0.828125
# 0.7734375
# 0.171875
# 0.11410165094812996
# 0.45194145326220503
