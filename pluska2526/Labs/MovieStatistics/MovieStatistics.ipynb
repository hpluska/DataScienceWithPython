# %% [markdown]
# # Movie Statistics

# %% [markdown]
# <h3 style="color: orange;">Introduction<hr style="color:black;"></h3>

# %% [markdown]
# You just got a very cool job in the film industry! Your first assignment is to do some research on the content produced by streaming services in the last few years. You’re putting together information for a report on the kinds of films being produced as well as any patterns that might be worth exploring further.

# %% [markdown]
# <h3 style="color: orange;">Install Anaconda<hr style="color:black;"></h3>

# %% [markdown]
# In this lab you will be running some Python code snippets.  This will require that you have the proper *kernel* installed.  The Python kernel will act as the computational engine for executing your Python code and sending the output back to the interface (e.g., a Jupyter Notebook cell).
#
# * To get started navigate to [Anaconda](https://anaconda.org/)
# * Locate the Free Download link in the top right corner
# * Click the Get Started button
# * Select the Sign Up with Email option <br> <img src = "images/AnacondaSignup.png">
# * Type your school email and make up a password, then click the button to submit
# * Check your email and open the Welcome email from Anaconda <br> <img src = "images/AnacondaWelcome.png">
# * Complete the prompts (or click skip when available)
# * Click the Distribution Installers <br><img src = "images/AnacondaInstall.png">
# * Locate the Anaconda execution file in your downloads and click on it to install (This will take awhile so be patient!)

# %% [markdown]
# <h3 style="color: orange;">Explore the dataset<hr style="color:black;"></h3>

# %% [markdown]
# To get started, you will explore some data about films and documentaries produced by Netflix. The dataset you’ll be using is a modified version of one found on the website [Kaggle](https://www.kaggle.com/). Your dataset includes 503 films with the following variables:

# %% [markdown]
# * **title**: title of the film
# * **genre**: genre of the film
# * **language**: primary language of the film
# * **year**: year the film premiered
# * **runtime**: length of the film in minutes
# * **score**: film rating of 1 to 10 (worst to best) from the website [IMDb](https://www.imdb.com/)

# %% [markdown]
# <h3 style="color: orange;">Explore the variables<hr style="color:black;"></h3>

# %% [markdown]
# ### **Language**

# %% [markdown]
# The table that follows gives the count of films in each language.

# %% [markdown]
# <img src = "images/Language.png">

# %% [markdown]
# Using the table, figure out the answer to the following questions. Record your answer by assigning to the correct variable.  After you assign an answer to the variable, hit the play button (▶| or hold down the `shift` key and press `return` or `enter`.)

# %% [markdown]
# **QUESTION 1** There are clearly a lot of films that have English as their primary language. Of the 503 films, what proportion have English as their primary language?  Replace the question marks below with your answer to assign your answer to the variable *proportionEnglish*.  When you are done, hit the play button (▶| or hold down the `shift` key and press `return` or `enter`.)

# %%
proportionEnglish = .72

# %% [markdown]
# <div style="background-color: #f0f0f0; padding: 20px;">
# Notice when you hit the play button you are prompted to select a "kernel" at the top of the VS Code environment.
#
# From the menu, select "Python Environment".  If there are more than 1 Python environments to choose from, select the version indicated in the screen shot below.
#
# <img src = "images/SelectKernel.png">
#
# To run code cells in Jupyter notebooks requires that you have the ipykernal installed.  If prompted select, "Install" to add this package. (You may not see this warning depending on your setup)
#
# <img src = "images/ipykernal.png">
# </div>

# %% [markdown]
# **QUESTION 2** What is the ratio of English-language films to films in a single language that is NOT English? Replace the question marks below with your answer to assign your answer to the variable *englishToNonEnglish*. When you are done, hit the play button (▶| or hold down the `shift` key and press `return` or `enter`.)

# %%
englishToNonEnglish = 2.95

# %% [markdown]
# **QUESTION 3** What proportion of the films has multiple primary languages? Replace the question marks below with your answer to assign your answer to the variable *multipleLanguages*. When you are done, hit the play button (▶| or hold down the `shift` key and press `return` or `enter`.)

# %%
multipleLanguages = .04

# %% [markdown]
# **QUESTION 4** Based on the questions you’ve just answered, write a few sentences summarizing what you found out about film languages. Give all proportions as percentages to help readers of your research report better understand your findings.

# %% [markdown]
# <span style="color:red">Answers may vary... But complete sentences MUST be used.  And the information in questions 1, 2, and 3 must be summarized below.</span>

# %% [markdown]
# ### **IMDb Score**

# %% [markdown]
# Now, take a look at all the IMDb scores! Are most films rated around the same score? Are there some extremely low or high scores?

# %% [markdown]
# <img src = "images/IMDbScores.png">
#
# **Mean**: 6.3
#
# **Standard Deviation**: 1.0

# %% [markdown]
# **QUESTION 5** Using the plot and summary statistics, describe the distribution of IMDb scores.

# %% [markdown]
# <span style="color:red">Answers may vary... But complete sentences MUST be used.  The mean and average should be included with the summary, along with the fact that the data is skewed left.</span>

# %% [markdown]
# ### **Genre**

# %% [markdown]
# **QUESTION 6** Your colleague is helping you with your research.  They will be writing up the summary for the genre variable.  Which summary statistics might your colleague include in their summary of the film genres? Replace the question marks below with your answer to assign your answer to the variable *summaryStatistic".  *Make sure you put quotation marks around your answer.*  Why might this be important.  When you are done, hit the play button (▶| or hold down the `shift` key and press `return` or `enter`.)

# %%
#Answers my vary, but one of the following is correct: frequency, proportion, percentage
summaryStatistic = ???

# %% [markdown]
# ### **Runtime**

# %% [markdown]
# Your colleague used analytics software to create a summary of the runtime variable. The software program has a default setting for numeric variables that outputs a distribution plot, the mean, and the standard deviation. The analytics software produced the following plot and statistics for the runtimes:

# %% [markdown]
# <img src = "images/Runtime.png">
#
# **Mean**: 92.5
#
# **Standard Deviation**: 28.4

# %% [markdown]
# **QUESTION 7** Based on the distribution plot, what concerns might you have with the default summary statistics used by the analytics software?

# %% [markdown]
# <span style="color:red">Answers may vary... But complete sentences MUST be used.  The mean may not be a good measure as the data is skewed left.</span>

# %% [markdown]
# **QUESTION 8** Which alternative statistics could your colleague use in this case?

# %% [markdown]
# <span style="color:red">ICQ might be the most common answer.  A better choice is using a rank value.  </style>

# %% [markdown]
# <h3 style="color: orange;">Explore the relationships<hr style="color:black;"></h3>

# %% [markdown]
# Next, you want to explore some relationships between variables. Aggregating data across genres and languages may give you some insights.

# %% [markdown]
# <u>IMDb Score by Genre</u>

# %% [markdown]
# You want to know if any genres have particularly high IMDb scores, so you look at a table of means and standard deviations of IMDb scores for each genre.

# %% [markdown]
# **QUESTION 9** Describe what you learn about IMDb scores across genres from the means and standard deviations in the table.

# %% [markdown]
# <span style="color:red">Answers may vary... But complete sentences MUST be used.  </span>

# %% [markdown]
# <u>Runtime by Language</u>

# %% [markdown]
# You are wondering if there are any differences in the length of films across languages.

# %% [markdown]
# <img src = "images/RuntimeLanguage.png">

# %% [markdown]
# **QUESTION 10** Describe what you learn about film runtimes across languages from the means and standard deviations in the table.

# %% [markdown]
# <span style="color:red">Answers may vary... But complete sentences MUST be used.  </span>

# %% [markdown]
# <u>Runtime by IMDb Score</u>

# %% [markdown]
# For your final exploration, you’ve just added the following plot and summary statistic to your report.

# %% [markdown]
# <img src = "images/IMDbScoresRuntime.png">
#
# **Correlation Coefficient**: 0.92

# %% [markdown]
# Your colleague is concerned there may be an error. The plot and the correlation coefficient don’t match.

# %% [markdown]
# **QUESTION 11** What does the plot tell you about the relationship between runtime and IMDb score?

# %% [markdown]
# <span style="color:red">Answers may vary... But complete sentences MUST be used.  The answer must indicate that there is no correlation or very little </span>

# %% [markdown]
# **QUESTION 12** What does the correlation coefficient tell you about the relationship between runtime and IMDb score?

# %% [markdown]
# <span style="color:red">Answers may vary... But complete sentences MUST be used. The answer must indicate that the correlation is closer to 0 not 1 </span>

# %% [markdown]
# <h3 style="color: orange;">Reflect on this lesson<hr style="color:black;"></h3>

# %% [markdown]
# In this lesson you interpreted and made choices about summary statistics.  You also wrote and ran Python code!
#
# You assigned values to the following variables,
#
# * proportionEnglish
# * englishToNonEnglish
# * multipleLanguages
# * summaryStatistics
#
# Variables in Python are containers for storing data values and are essential for controlling the memory in our programs. You can think of variables like a box that can hold a value.
#
# Every Python variable has the following,
#
# * a name (for example, "proportionEnglish")
# * a value (the content of the container)
#
# The value of some variables must be stored in quotes.  These type of variables are called *String* type variables.  Numerical values however are not stored in quotes.  As you go through the course, you will make extensive use of variables in the programs you write.

# %% [markdown]
# <h3 style="color: orange;">Submit this assignment<hr style="color:black;"></h3>

# %% [markdown]
# Locate the *Run All* option at the top of this document and click it.
#
# Review the document to make sure you do not have any errors.
#
# Save this file and push this repository to GitHub just like you did in the previous lesson.  If you get stuck, review the GitHub workshop.
