# %% [markdown]
# # CS 133 Foundations of Data Science - Midterm
#
# This exam has 10 questions and is worth 50 points. The difficulty lies in that some of the later questions build on earlier ones. If you find that you cannot complete a question that later questions rely on, please attempt to do all of the questions anyway. I will award partial credit to answers even if they don't run correctly due to reliance on earlier questions.
#
# ### Instructions
#
# - Open up the jupyter notebook server (i.e., any assignment or just [click here](https://jupyter.boisestate.edu/new?image=boisestate/jupyterlab-fds:latest&path=sandbox.ipynb) and upload this notebook (you could also do this locally or on Google Colab if you are familiar with those)
# - Save regularly by downloading the notebook (`file`->`Download`)
# - When you are ready to submit, be sure to submit both the .ipynb and .html formats as usual.
# - Note that there is no okpy autograder here like there is for your assignments.
#
# ### General Hints
#
# - You will be using the datascience Table a lot
# - Refer to the documentation for [Table](http://data8.org/datascience/tables.html)
# - You can use previous homeworks, lectures, labs, notes
# - You can use the Internet
# - You can NOT use other people to help you (no chatting, no phones, etc.)
# - You can NOT use AI tools (e.g., ChatGPT or Code GenAI tools)

# %% [markdown]
# ## 1. Tables  and Data
#
# When Dr. Kennington rides his bike to work, he sometimes comes across strange things in the bike lane. He started keeping a log of the things that he has seen. Run the cell below to create a list of some of these items:

# %%
from datascience import *  # let us not forget to import what we need


items = make_array('coke can',
                   'pepsi can',
                   'tube of toothpaste',
                   'axe',
                   'coke can',
                   'playing cards',
                   'spark plug',
                   'hammer',
                   'cycling glove',
                   'cotton glove',
                   'golf ball',
                   'pair of slippers',
                   'hair brush',
                   'paint brush',
                   'coke can',
                   'nitrile glove',
                   'leather glove',
                   'toy stuffed lemur',
                   'beach towel',
                   'contact lens case')

# %% [markdown]
# #### 1.1) Make a table named `table` which has a column named `item` which is made up of the `items` array that we made in the above cell.

# %%
table = ...

# %%
table

# %% [markdown]
# #### 1.2) Use the following function `glove_finder(x)` which takes a string and returns `y` if the string has the string `y` in it, otherwise it returns the original string.
#
# You need to complete the function by replacing '?' with the proper string in order for this function to find the string `glove`.

# %%
def glove_finder(x, y='?'):
    if y in x: return y
    return x

# %% [markdown]
# #### 1.3) Use the `glove_finder` function to create a new column in `table` called `new_item`. The new column should be an application of the `glove_finder` function on the `item` column.
#
# * Hint: use the `apply` method/function.

# %%
table = ...

# %% [markdown]
# ## 2.) Tables and Counting

# %% [markdown]
# #### 2.1 Make a new table that contains the counts of the items in `new_item`.
#
# * `group` might be usful here.

# %%
counts = ...

counts

# %% [markdown]
# #### 2.2) Write a function called `get_count` which takes in a variable `x` and returns the count of `x` as found in the `new_item` column of the `counts` table.
#
# Hints:
#
# * `counts.where(...)` might be useful
# * The `column` method/function might be useful
# * Note the return type! You want to make sure it's a float, not a list
# * Also note: there are many ways to write this function using other counting methods.

# %%
def get_count(x):
    ...

# %% [markdown]
# #### 2.2) Create a new column in `table` called 'count'. Use the `get_count` method on the `new_item` column to create this column.
#
# * The `apply` method will be useful here.

# %%
table = ...

table

# %% [markdown]
# #### 2.3) Find the total count of items and store it in the `total_count` variable.
#
# - You need to do this using code, do not just input a number!

# %%
total_count = ...

# %% [markdown]
# #### 2.4) Create a new column in `table` called `prob`. Each row should represent an estimated probability for the item in `new_item`.
#
# - Use the `get_prob(x)` and `apply` functions.

# %%
def get_prob(x):
    return x / total_count

table = ...

table

# %%
# Be sure to download your notebook and back it up before moving on!

# %% [markdown]
# ## 3.) Short-answer questions
#
# **Hints:**
#
# * No code needed on these questions
# * Answers go into the Markdown cells that follow each question

# %% [markdown]
# #### 3.1) What is the probability of seeing a glove in the bike lane?

# %% [markdown]
# (answer here)

# %% [markdown]
# #### 3.2) What was the purpose of questions 1.2 and 1.3? Why is that useful? Is there another case in the data where doing something similar might be useful?

# %% [markdown]
# (answer here)
